# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\priya\Desktop\youtubers.csv")
df
# Out:
#      Rank              Username  subscribers         Country       Visits  \
# 0       1               tseries    249500000           India      86200.0
# 1       2               MrBeast    183500000  Estados Unidos  117400000.0
# 2       3             CoComelon    165500000         Unknown    7000000.0
# 3       4              SETIndia    162600000           India      15600.0
# 4       5         KidsDianaShow    113500000         Unknown    3900000.0
# ..    ...                   ...          ...             ...          ...
# 995   996          hamzymukbang     11700000  Estados Unidos     397400.0
# 996   997            Adaahqueen     11700000           India    1100000.0
# 997   998  LittleAngelIndonesia     11700000         Unknown     211400.0
# 998   999          PenMultiplex     11700000           India      14000.0
# 999  1000         OneindiaHindi     11700000           India       2200.0
#
#        Likes Comments                                              Links
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot.scatter(x='subscribers',y='Rank')
# Out:
# <Axes: xlabel='subscribers', ylabel='Rank'>

# %%
df2=df.head(20)  #top 20 youtubers
df2
# Out:
#     Rank              Username  subscribers         Country       Visits  \
# 0      1               tseries    249500000           India      86200.0
# 1      2               MrBeast    183500000  Estados Unidos  117400000.0
# 2      3             CoComelon    165500000         Unknown    7000000.0
# 3      4              SETIndia    162600000           India      15600.0
# 4      5         KidsDianaShow    113500000         Unknown    3900000.0
# 5      6             PewDiePie    111500000  Estados Unidos    2400000.0
# 6      7    LikeNastyaofficial    107500000         Unknown    2600000.0
# 7      8           VladandNiki    101400000         Unknown    4100000.0
# 8      9       zeemusiccompany     99700000           India      74300.0
# 9     10                   WWE     97200000  Estados Unidos     184500.0
# 10    11             BLACKPINK     91300000  Estados Unidos     863200.0
# 11    12    GoldminesTelefilms     89700000           India      34600.0
# ...

# %%
df2.plot.pie(y='subscribers')
#0,1,2... are the ranks
# Out:
# <Axes: ylabel='subscribers'>

# %%
#filtering
df[df['subscribers']>1000000]
# Out:
#      Rank              Username  subscribers         Country       Visits  \
# 0       1               tseries    249500000           India      86200.0
# 1       2               MrBeast    183500000  Estados Unidos  117400000.0
# 2       3             CoComelon    165500000         Unknown    7000000.0
# 3       4              SETIndia    162600000           India      15600.0
# 4       5         KidsDianaShow    113500000         Unknown    3900000.0
# ..    ...                   ...          ...             ...          ...
# 995   996          hamzymukbang     11700000  Estados Unidos     397400.0
# 996   997            Adaahqueen     11700000           India    1100000.0
# 997   998  LittleAngelIndonesia     11700000         Unknown     211400.0
# 998   999          PenMultiplex     11700000           India      14000.0
# 999  1000         OneindiaHindi     11700000           India       2200.0
#
#        Likes Comments                                              Links
# ...

# %%
df[df['subscribers']>1000000 & (df['Rank']<10)]  #this command will follow the first condition
# Out:
#      Rank              Username  subscribers         Country       Visits  \
# 0       1               tseries    249500000           India      86200.0
# 1       2               MrBeast    183500000  Estados Unidos  117400000.0
# 2       3             CoComelon    165500000         Unknown    7000000.0
# 3       4              SETIndia    162600000           India      15600.0
# 4       5         KidsDianaShow    113500000         Unknown    3900000.0
# ..    ...                   ...          ...             ...          ...
# 995   996          hamzymukbang     11700000  Estados Unidos     397400.0
# 996   997            Adaahqueen     11700000           India    1100000.0
# 997   998  LittleAngelIndonesia     11700000         Unknown     211400.0
# 998   999          PenMultiplex     11700000           India      14000.0
# 999  1000         OneindiaHindi     11700000           India       2200.0
#
#        Likes Comments                                              Links
# ...

# %%
df[df['Username'].str.contains('MrBeast')]
# Out:
#      Rank  Username  subscribers         Country       Visits    Likes  \
# 1       2   MrBeast    183500000  Estados Unidos  117400000.0  5300000
# 136   137  MrBeast2     31300000  Estados Unidos   83100000.0  5000000
#
#     Comments                                              Links
# 1      18500  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 136    11600  http://youtube.com/channel/UC4-79UOlP48-QNGgCk...

# %%
df['Username', 'Visits', 'Likes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\anaconda\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\anaconda\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Username', 'Visits', 'Likes')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Username', 'subscribers', 'Country', 'Visits', 'Likes',
#        'Comments', 'Links'],
#       dtype='object')

# %%
df['Username']
# Out:
# 0                   tseries
# 1                   MrBeast
# 2                 CoComelon
# 3                  SETIndia
# 4             KidsDianaShow
#                ...
# 995            hamzymukbang
# 996              Adaahqueen
# 997    LittleAngelIndonesia
# 998            PenMultiplex
# 999           OneindiaHindi
# Name: Username, Length: 1000, dtype: object

# %%
df.iloc[2,1]  #row 2, column 1.
# Out:
# 'CoComelon'
